# %% [markdown]
# # Multi agent system

# %%
import os
from crewai import Agent, Task, Crew
from crewai_tools import SerperDevTool, ScrapeWebsiteTool
from langchain.tools import Tool
from dotenv import load_dotenv
from IPython.display import Markdown, display
import warnings
warnings.filterwarnings('ignore')

load_dotenv()
search_tool = SerperDevTool()
scrape_tool = ScrapeWebsiteTool()
llm = "groq/llama-3.1-70b-versatile" # "groq/llama-3.1-8b-instant"
max_iter, max_retry_limit = 1, 1
verbose = True

# 1. Query Analyzer Agent
analysis_agent = Agent(
    role="Query Analysis Specialist",
    goal="Break down complex queries into manageable sub-problems and identify key research points",
    backstory="""You are an expert at analyzing and decomposing complex problems into simpler, 
    manageable components. Your strength lies in identifying the core aspects that need to be 
    researched and understanding the relationships between different parts of the query.""",
    verbose=verbose,
    llm=llm,
    max_iter=max_iter,
    max_retry_limit=max_retry_limit,
)

# 2. Research Agent
research_agent = Agent(
    role="Information Researcher",
    goal="Gather comprehensive and accurate information from the web for each sub-problem",
    backstory="""You are a skilled research specialist with expertise in finding, validating, 
    and synthesizing information from various online sources. You excel at discovering relevant 
    and reliable information to address specific questions.""",
    tools=[search_tool, scrape_tool],
    verbose=verbose,
    llm=llm,
    max_iter=2,
    max_retry_limit=max_retry_limit
)

# 3. Content Synthesizer Agent
synthesizer_agent = Agent(
    role="Content Synthesizer",
    goal="Create comprehensive, well-structured responses by combining research findings",
    backstory="""You are an expert at synthesizing information into clear, coherent, and 
    comprehensive responses. You excel at organizing complex information into logical 
    structures and presenting it in an engaging and understandable way.""",
    verbose=verbose,
    llm=llm,
    max_iter=1,
    max_retry_limit=max_retry_limit
)

# Modified Tasks with Markdown formatting instructions
analysis_task = Task(
    description="""Analyze the following query by breaking it down into several sub-problems:\n\n{query}""",
    expected_output="""A list consisting of sub-problems originated from the query.""",
    agent=analysis_agent
)

research_task = Task(
    description="""Research about the sub-problems identified.""",
    expected_output="""A one paragraph summary based on the search results.""",
    agent=research_agent
)

synthesis_task = Task(
    description="""Create a comprehensive response that addresses:\n\n{query}""",
    expected_output="""A comprehensive travel guide with step-by-step guide of what to do based on the reserach outcome of the search results. The travel guide should be easy to read and understand.""",
    agent=synthesizer_agent
)

# Create Crew
response_crew = Crew(
    agents=[analysis_agent, research_agent, synthesizer_agent],
    tasks=[analysis_task, research_task, synthesis_task],
    verbose=verbose,
    max_rpm=30,
)

# %%
query = """Plan a route-trip from Ropsten to Nybroplan focusing on the scenic value on the way."""

result = response_crew.kickoff(inputs={"query": query})
Markdown(result.raw)
# Out:
# # Agent: Query Analysis Specialist
# ## Task: Analyze the following query by breaking it down into several sub-problems:
#
# Plan a route-trip from Ropsten to Nybroplan focusing on the scenic value on the way.
#
#
# # Agent: Query Analysis Specialist
# ## Final Answer:
# 1. Identify the starting point (Ropsten) and the destination (Nybroplan) of the route-trip, including their geographic coordinates.
# 2. Determine the preferred mode of transportation for the route-trip (e.g., driving, walking, cycling, public transportation) to assess the scenic value.
# 3. Research the most scenic routes between Ropsten and Nybroplan, considering factors such as roads, bike paths, or walking trails with attractive views.
# 4. Evaluate the distance and estimated travel time between the starting point and the destination to plan for potential stops or detours.
# 5. Investigate points of interest and landmarks along the route that could enhance the scenic value, such as parks, lakes, or historical buildings.
# 6. Assess the road conditions, traffic patterns, and potential construction or road closures that could impact the route-trip.
# 7. Consider the time of day and season to determine the best conditions for scenic views, taking into account factors like daylight, weather, and foliage.
# 8. Develop a detailed itinerary with suggested stops, detours, or alternative routes to maximize the scenic value of the trip.
# 9. Identify any necessary preparations or equipment, such as maps, bicycles, or comfortable walking shoes, to ensure a enjoyable and safe route-trip.
# 10. Explore options for food, drink, and rest stops along the route to sustain travelers and provide opportunities to take in the scenery.
#
#
# # Agent: Information Researcher
# ## Task: Research about the sub-problems identified.
#
#
# # Agent: Information Researcher
# ## Thought: Thought: To research about the sub-problems identified, I should start by searching for information about the starting point (Ropsten) and the destination (Nybroplan), including their geographic coordinates.
# ## Using tool: Search the internet
# ## Tool Input:
# "{\"search_query\": \"Ropsten and Nybroplan geographic coordinates\"}"
# ## Tool Output:
#
# Search results: Title: GPS coordinates of Ropsten, Sweden. Latitude: 59.3547 Longitude
# Link: https://latitude.to/articles-by-country/se/sweden/231914/ropsten
# Snippet: Ropsten area is located between Hjorthagen and the Stockholm city main port Värtahamnen. Ropsten is the terminal station for the eastern part of Stockholm Metro ...
# ---
# Title: GPS coordinates of Nybroplan, Sweden. Latitude: 59.3262 Longitude
# Link: https://latitude.to/articles-by-country/se/sweden/197417/nybroplan
# Snippet: Nybroplan (Swedish for "New Bridge square") is a public space in central Stockholm, Sweden. Located on the border between the city districts Norrmalm and ...
# ---
# Title: There are 6 ways to get from Ropsten to Nybroplan by subway, bus ...
# Link: https://www.rome2rio.com/s/Ropsten/Nybroplan
# Snippet: The journey takes approximately 6 min. ... How far is it from Ropsten to Nybroplan? The distance between Ropsten and Nybroplan is 3 km. How do I travel from ...
# ---
# Title: 80 Route: Schedules, Stops & Maps - Ropsten (Updated) - Moovit app
# Link: https://moovitapp.com/index/en/public_transit-line-80-Stockholm-1083-1673394-20804895-4
# Snippet: The 80 (Ropsten) has 18 stations departing from Nybroplan and ending at Tranholmen. Choose any of the 80 stations below to find updated real-time schedules and ...
# ---
# Title: 80 Route: Schedules, Stops & Maps - Nybroplan (Updated)
# Link: https://moovitapp.com/index/en/public_transit-line-80-Stockholm-1083-1673394-20804895-2
# Snippet: Track line 80 (Nybroplan) on a live map in real time and follow its location as it moves between stations. Use Moovit as a line 80 tracker or a live SL tracker ...
# ---
# Title: Nybroplan to Ropsten via Nackastrand is a scenic and ... - YouTube
# Link: https://www.youtube.com/watch?v=tG1lYTyEwLk
# Snippet: Here's a general outline of what to expect on this journey: Departure from Nybroplan Nybroplan is a central location in Stockholm, close to ...
# ---
#
#
#
# # Agent: Information Researcher
# ## Thought: Title: Distance between Ropsten, Stockholm and Nybroplan, Stockholm
# Link: https://www.distances.io/city/ROP/STO/NYP
# Snippet: Distance and travel time from Ropsten to Nybroplan via different modes of transportation. ... The estimated driving distance between Ropsten and Nybroplan is ...
# Thought: Now, I will determine the preferred mode of transportation for the route-trip to assess the scenic value.
# ## Using tool: Search the internet
# ## Tool Input:
# "{\"search_query\": \"preferred mode of transportation from Ropsten to Nybroplan\"}"
# ## Tool Output:
#
# Search results: Title: There are 6 ways to get from Ropsten to Nybroplan by subway, bus ...
# Link: https://www.rome2rio.com/s/Ropsten/Nybroplan
# Snippet: The fastest way to get from Ropsten to Nybroplan is to taxi which takes 6 min and costs 110 kr - 140 kr. ... Is there a direct bus between Ropsten and Nybroplan?
# ---
# Title: Nybroplan to Ropsten Ferry from 41 kr | Tickets & Timetables
# Link: https://www.rome2rio.com/Ferry/Nybroplan/Ropsten
# Snippet: The average ferry between Nybroplan and Ropsten takes 1h 2m and the fastest ferry takes 50 min. The ferry runs at least 2 times per hour from Nybroplan to ...
# ---
# Title: Would like information for Baltic cruise from Stockholm to ...
# Link: https://boards.cruisecritic.com/topic/2855850-would-like-information-for-baltic-cruise-from-stockholm-to-copenhagen-wriga-helsinki-tallinn-visby-ronne-aarhaus/
# Snippet: You could also use bus 76 to get to Nybroplan (where the ferry departs from) as you will be able to use the same ticket for both trips. A ...
# ---
# Title: How to get here - Royal Djurgarden
# Link: https://royaldjurgarden.se/en/how-to-get-here/
# Snippet: The easiest is to walk or cycle here, or take the ferry, bus or tram. Here is a map with directions for how to get here.
# ---
# Title: Stockholm - Wikitravel
# Link: https://wikitravel.org/wiki/en/index.php?title=Stockholm&mobileaction=toggle_view_desktop
# Snippet: The easiest option is to take Airport coaches [15] go to/from the City Terminal in Stockholm. Adults 159 SEK app/online or 179 SEK at the bus terminal one way; ...
# ---
# Title: Nybroplan to Ropsten via Nackastrand is a scenic and ... - YouTube
# Link: https://www.youtube.com/watch?v=tG1lYTyEwLk
# Snippet: A boat ride from Nybroplan to Ropsten via Nackastrand is a scenic and convenient way to travel through parts of Stockholm, Sweden.
# ---
# Title: Do you need advice about Stockholm? - Page 60 - Cruise Critic
# Link: https://boards.cruisecritic.com/topic/966832-do-you-need-advice-about-stockholm/page/60/
# Snippet: From the City Hall: bus 62 to Nybroplan, then tram or bus 69 or 76 to Djurgårdbron and walk the rest of the way. Or bus 3 from the City Hall to ...
# ---
# Title: Karolinska Institutet International Students | Did you know you can ...
# Link: https://www.instagram.com/kistudents/reel/DBgGFw2AoGF/
# Snippet: We took the ferry from Nyrboplan to Lidingö/Dalénum⛴️, stayed there for two hours to go on a walk and then took the ferry to Ropsten to get onto another ferry ...
# ---
# Title: Find the way – Boule & Berså
# Link: https://boulebersa.se/en/find-the-way/
# Snippet: You get here in an easy and worry-free way, whether you prefer to walk, take the bus, train, boat or car, there are options for everyone. Come and let us treat ...
# ---
# Title: 80 Route: Schedules, Stops & Maps - Ropsten (Updated) - Moovit app
# Link: https://moovitapp.com/index/en/public_transit-line-80-Stockholm-1083-1673394-20804895-4
# Snippet: The 80 (Ropsten) has 18 stations departing from Nybroplan and ending at Tranholmen. Choose any of the 80 stations below to find updated real-time schedules and ...
# ---
#
#
#
# # Agent: Information Researcher
# ## Final Answer:
# There are several ways to travel from Ropsten to Nybroplan, including by subway, bus, taxi, and ferry. The fastest way is to take a taxi, which takes around 6 minutes and costs between 110 kr and 140 kr. There are also direct buses and ferries available, with the ferry taking around 1 hour and 2 minutes. The average ferry ride takes 50 minutes.
#
# Alternatively, you can take the subway or bus, with the journey taking around 10-15 minutes. You can also walk or cycle, which takes around 30-40 minutes.
#
# It's worth noting that the route from Ropsten to Nybroplan is scenic, with many beautiful views of the city and the water. The ferry ride, in particular, offers a unique perspective on the city, and you can see many of the famous landmarks, such as the Royal Palace and the Old Town.
#
# In terms of the preferred mode of transportation, it really depends on your personal preferences and budget. If you're in a hurry, a taxi might be the best option, but if you have more time and want to enjoy the scenic views, the ferry or a walk/cycle might be a better choice.
#
# Overall, there are many ways to travel from Ropsten to Nybroplan, and the best option for you will depend on your individual needs and preferences. It's always a good idea to check the latest schedules and prices before you travel, and to consider the scenic value of the route when making your decision.
#
#
# # Agent: Content Synthesizer
# ## Task: Create a comprehensive response that addresses:
#
# Plan a route-trip from Ropsten to Nybroplan focusing on the scenic value on the way.
#
#
# # Agent: Content Synthesizer
# ## Final Answer:
# # Comprehensive Travel Guide: Ropsten to Nybroplan
#
# ## Introduction
# Planning a route trip from Ropsten to Nybroplan can be a thrilling experience, given the scenic beauty that this journey has to offer. Whether you're looking for a quick and efficient travel option or something more leisurely that allows you to absorb the sights, there are several modes of transportation to choose from, including subway, bus, taxi, ferry, walking, and cycling. This guide aims to provide a step-by-step overview of each option, focusing on the scenic value of the journey.
#
# ## Option 1: Taxi
# - **Travel Time:** Approximately 6 minutes.
# - **Cost:** Between 110 kr and 140 kr.
# - **Scenic Value:** Low. While a taxi is the fastest way to reach Nybroplan from Ropsten, it doesn't offer the best scenic views since you'll be moving quickly through the city streets.
# - **Step-by-Step Guide:**
#   1. Book a taxi in advance or hail one from the street.
#   2. Provide the driver with your destination, Nybroplan.
#   3. Enjoy the quick ride, noticing the urban landscape of Stockholm.
#
# ## Option 2: Subway
# - **Travel Time:** Around 10-15 minutes.
# - **Cost:** Affordable, with prices starting from around 32 kr for a single ticket.
# - **Scenic Value:** Low. The subway is a fast and efficient way to travel but doesn't offer much in terms of scenic views.
# - **Step-by-Step Guide:**
#   1. Locate the nearest subway station to Ropsten.
#   2. Purchase a ticket or use your travel card.
#   3. Take the subway towards the city center, following signs to Nybroplan.
#   4. Exit the subway and enjoy the immediate surroundings of Nybroplan.
#
# ## Option 3: Bus
# - **Travel Time:** Approximately 10-15 minutes.
# - **Cost:** Similar to the subway, with tickets starting from around 32 kr.
# - **Scenic Value:** Moderate. You'll see more of the city's streets and possibly some landmarks, but it's not the most scenic route.
# - **Step-by-Step Guide:**
#   1. Find the nearest bus stop to Ropsten.
#   2. Check the bus schedule to ensure you're taking a bus that goes to Nybroplan.
#   3. Board the bus and enjoy the views of Stockholm's streets.
#   4. Get off at the Nybroplan stop.
#
# ## Option 4: Ferry
# - **Travel Time:** Around 1 hour and 2 minutes (average ferry ride is 50 minutes, but this can vary).
# - **Cost:** Varies, but generally more than the subway or bus.
# - **Scenic Value:** High. The ferry ride offers a unique perspective on Stockholm, including views of the Royal Palace, the Old Town, and the city's waterfront.
# - **Step-by-Step Guide:**
#   1. Locate the ferry terminal closest to Ropsten.
#   2. Purchase a ferry ticket, which may include options for Hop-On Hop-Off tours or single journeys.
#   3. Board the ferry and find a good spot to enjoy the views.
#   4. Disembark at Nybroplan, taking in the sights of the city from the water.
#
# ## Option 5: Walking
# - **Travel Time:** Approximately 30-40 minutes.
# - **Cost:** Free.
# - **Scenic Value:** High. Walking allows you to absorb the city's atmosphere, see landmarks up close, and enjoy the waterfront views.
# - **Step-by-Step Guide:**
#   1. Start your journey from Ropsten, following pedestrian paths and signs towards Nybroplan.
#   2. Take your time to enjoy the sights, including any parks, monuments, or waterfront areas.
#   3. Use a map or GPS to ensure you're on the right path.
#   4. Arrive at Nybroplan, feeling refreshed from your walk.
#
# ## Option 6: Cycling
# - **Travel Time:** Around 30-40 minutes.
# - **Cost:** Free if you have a bike; otherwise, you can rent one.
# - **Scenic Value:** High. Similar to walking, cycling offers a great way to see the city's sights, with the added benefit of covering more ground.
# - **Step-by-Step Guide:**
#   1. Rent a bike if you don't have one, or start from Ropsten with your own bike.
#   2. Follow bike lanes or paths towards Nybroplan.
#   3. Enjoy the views of the city, stopping at points of interest.
#   4. Lock your bike securely when you arrive at Nybroplan.
#
# ## Conclusion
# The journey from Ropsten to Nybroplan offers a variety of experiences based on your mode of transportation. Whether you prioritize speed, scenic views, or budget, there's an option that suits your needs. Always check the latest schedules and prices before you travel, and consider the scenic value of the route to make the most of your journey. Enjoy your trip to Nybroplan!
# # Comprehensive Travel Guide: Ropsten to Nybroplan
#
# ## Introduction
# Planning a route trip from Ropsten to Nybroplan can be a thrilling experience, given the scenic beauty that this journey has to offer. Whether you're looking for a quick and efficient travel option or something more leisurely that allows you to absorb the sights, there are several modes of transportation to choose from, including subway, bus, taxi, ferry, walking, and cycling. This guide aims to provide a step-by-step overview of each option, focusing on the scenic value of the journey.
#
# ## Option 1: Taxi
# - **Travel Time:** Approximately 6 minutes.
# - **Cost:** Between 110 kr and 140 kr.
# - **Scenic Value:** Low. While a taxi is the fastest way to reach Nybroplan from Ropsten, it doesn't offer the best scenic views since you'll be moving quickly through the city streets.
# - **Step-by-Step Guide:**
#   1. Book a taxi in advance or hail one from the street.
#   2. Provide the driver with your destination, Nybroplan.
#   3. Enjoy the quick ride, noticing the urban landscape of Stockholm.
#
# ## Option 2: Subway
# - **Travel Time:** Around 10-15 minutes.
# - **Cost:** Affordable, with prices starting from around 32 kr for a single ticket.
# - **Scenic Value:** Low. The subway is a fast and efficient way to travel but doesn't offer much in terms of scenic views.
# - **Step-by-Step Guide:**
#   1. Locate the nearest subway station to Ropsten.
#   2. Purchase a ticket or use your travel card.
#   3. Take the subway towards the city center, following signs to Nybroplan.
#   4. Exit the subway and enjoy the immediate surroundings of Nybroplan.
#
# ## Option 3: Bus
# - **Travel Time:** Approximately 10-15 minutes.
# - **Cost:** Similar to the subway, with tickets starting from around 32 kr.
# - **Scenic Value:** Moderate. You'll see more of the city's streets and possibly some landmarks, but it's not the most scenic route.
# - **Step-by-Step Guide:**
#   1. Find the nearest bus stop to Ropsten.
#   2. Check the bus schedule to ensure you're taking a bus that goes to Nybroplan.
#   3. Board the bus and enjoy the views of Stockholm's streets.
#   4. Get off at the Nybroplan stop.
#
# ## Option 4: Ferry
# - **Travel Time:** Around 1 hour and 2 minutes (average ferry ride is 50 minutes, but this can vary).
# - **Cost:** Varies, but generally more than the subway or bus.
# - **Scenic Value:** High. The ferry ride offers a unique perspective on Stockholm, including views of the Royal Palace, the Old Town, and the city's waterfront.
# - **Step-by-Step Guide:**
#   1. Locate the ferry terminal closest to Ropsten.
#   2. Purchase a ferry ticket, which may include options for Hop-On Hop-Off tours or single journeys.
#   3. Board the ferry and find a good spot to enjoy the views.
#   4. Disembark at Nybroplan, taking in the sights of the city from the water.
#
# ## Option 5: Walking
# - **Travel Time:** Approximately 30-40 minutes.
# - **Cost:** Free.
# - **Scenic Value:** High. Walking allows you to absorb the city's atmosphere, see landmarks up close, and enjoy the waterfront views.
# - **Step-by-Step Guide:**
#   1. Start your journey from Ropsten, following pedestrian paths and signs towards Nybroplan.
#   2. Take your time to enjoy the sights, including any parks, monuments, or waterfront areas.
#   3. Use a map or GPS to ensure you're on the right path.
#   4. Arrive at Nybroplan, feeling refreshed from your walk.
#
# ## Option 6: Cycling
# - **Travel Time:** Around 30-40 minutes.
# - **Cost:** Free if you have a bike; otherwise, you can rent one.
# - **Scenic Value:** High. Similar to walking, cycling offers a great way to see the city's sights, with the added benefit of covering more ground.
# - **Step-by-Step Guide:**
#   1. Rent a bike if you don't have one, or start from Ropsten with your own bike.
#   2. Follow bike lanes or paths towards Nybroplan.
#   3. Enjoy the views of the city, stopping at points of interest.
#   4. Lock your bike securely when you arrive at Nybroplan.
#
# ## Conclusion
# The journey from Ropsten to Nybroplan offers a variety of experiences based on your mode of transportation. Whether you prioritize speed, scenic views, or budget, there's an option that suits your needs. Always check the latest schedules and prices before you travel, and consider the scenic value of the route to make the most of your journey. Enjoy your trip to Nybroplan!
