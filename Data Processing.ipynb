# %%
##Create the final data set
#Author :Santosh Kumar Udayakumar
#Function : This script loads data from the unzipped sl folder, which is extracted during the data extraction process from the Traffic Lab API. It creates the final dataset by combining Stops and Lines data.

#Load the libraries 

import pandas as pd
import xml.etree.ElementTree as ET

# %%
#Inspect the single XML file and identify the meaningful features 
# Parse the XML file
xml_file = 'sl_data/line_1_814_9011001081400000.xml'  # Replace with the path to your XML file
tree = ET.parse(xml_file)
root = tree.getroot()

# Define the namespace
ns = {'netex': 'http://www.netex.org.uk/netex'}

# Extract routes data
routes_data = []
for route in root.findall('.//netex:Route', ns):
    route_id = route.attrib.get('id')
    route_name = route.find('netex:Name', ns).text
    direction = route.find('netex:DirectionType', ns).text
    
    # Extract points in sequence for each route
    points_in_sequence = []
    for point in route.findall('.//netex:PointOnRoute', ns):
        point_id = point.attrib.get('id')
        order = point.attrib.get('order')
        ref = point.find('netex:RoutePointRef', ns).attrib.get('ref')
        points_in_sequence.append({
            'Point_ID': point_id,
            'Order': order,
            'RoutePointRef': ref
        })
    
    routes_data.append({
        'Route_ID': route_id,
        'Route_Name': route_name,
        'Direction': direction,
        'Points_in_Sequence': points_in_sequence
    })

# Create a DataFrame to store routes data
routes_df = pd.DataFrame(routes_data)

# Extract timetable and service journey data along with public and private codes
timetable_data = []
for journey in root.findall('.//netex:ServiceJourney', ns):
    journey_id = journey.attrib.get('id')
    transport_mode = journey.find('netex:TransportMode', ns).text
    
    # Extract operator, day types, and public/private codes
    operator_ref = journey.find('.//netex:OperatorRef', ns).attrib.get('ref')
    day_type_ref = journey.find('.//netex:DayTypeRef', ns).attrib.get('ref')
    
    # Extract LineRef to find public and private codes
    line_ref = journey.find('.//netex:JourneyPatternRef', ns).attrib.get('ref')
    line = root.find(f".//netex:Line[@id='{line_ref}']", ns)
    
    public_code = line.find('netex:PublicCode', ns).text if line is not None else None
    private_code = line.find('netex:PrivateCode', ns).text if line is not None else None
    
    # Extract passing times for each stop in the journey
    for passing_time in journey.findall('.//netex:TimetabledPassingTime', ns):
        stop_ref = passing_time.find('netex:StopPointInJourneyPatternRef', ns).attrib.get('ref')
        arrival_time = passing_time.find('netex:ArrivalTime', ns)
        departure_time = passing_time.find('netex:DepartureTime', ns)
        
        timetable_data.append({
            'Journey_ID': journey_id,
            'TransportMode': transport_mode,
            'OperatorRef': operator_ref,
            'DayTypeRef': day_type_ref,
            'PublicCode': public_code,
            'PrivateCode': private_code,
            'StopPointInJourneyPatternRef': stop_ref,
            'ArrivalTime': arrival_time.text if arrival_time is not None else None,
            'DepartureTime': departure_time.text if departure_time is not None else None
        })

# Create a DataFrame to store service journey timetable data
timetable_df = pd.DataFrame(timetable_data)

# Display the DataFrames
print(routes_df.head())   # Routes DataFrame
print(timetable_df.head()) # Timetable and service journey DataFrame with codes
# Out:
#                          Route_ID         Route_Name Direction  \
# 0  SE:001:Route:14010000577667337  Södra Hedvigslund  outbound
# 1  SE:001:Route:14010000577667012       Gullmarsplan   inbound
#
#                                   Points_in_Sequence
# 0  [{'Point_ID': 'SE:001:PointOnRoute:14010000577...
# 1  [{'Point_ID': 'SE:001:PointOnRoute:14010000577...
#                                 Journey_ID TransportMode  \
# 0  SE:001:ServiceJourney:14010000597098249           bus
# 1  SE:001:ServiceJourney:14010000597098249           bus
# 2  SE:001:ServiceJourney:14010000597098249           bus
# 3  SE:001:ServiceJourney:14010000597098249           bus
# 4  SE:001:ServiceJourney:14010000597098249           bus
#
#                         OperatorRef  \
# 0  SE:001:Operator:9013001003000000
# 1  SE:001:Operator:9013001003000000
# 2  SE:001:Operator:9013001003000000
# 3  SE:001:Operator:9013001003000000
# 4  SE:001:Operator:9013001003000000
#
#                                         DayTypeRef PublicCode PrivateCode  \
# 0  SE:001:DayType:bncpagqso7dvr0jmc2o233d3een6g00p       None        None
# 1  SE:001:DayType:bncpagqso7dvr0jmc2o233d3een6g00p       None        None
# 2  SE:001:DayType:bncpagqso7dvr0jmc2o233d3een6g00p       None        None
# 3  SE:001:DayType:bncpagqso7dvr0jmc2o233d3een6g00p       None        None
# 4  SE:001:DayType:bncpagqso7dvr0jmc2o233d3een6g00p       None        None
#
#                         StopPointInJourneyPatternRef ArrivalTime DepartureTime
# 0  SE:001:StopPointInJourneyPattern:1401941000012...        None      17:10:00
# 1  SE:001:StopPointInJourneyPattern:1401941000012...    17:17:00      17:17:00
# 2  SE:001:StopPointInJourneyPattern:1401941000012...    17:22:00      17:22:00
# 3  SE:001:StopPointInJourneyPattern:1401941000012...    17:24:13      17:24:13
# 4  SE:001:StopPointInJourneyPattern:1401941000012...    17:26:35      17:26:35

# %%
import pandas as pd
import xml.etree.ElementTree as ET
import glob
import os

# Function to extract data and Process all the lines data for time table 
def extract_from_xml(xml_file, private_code):
    # Parse the XML file
    tree = ET.parse(xml_file)
    root = tree.getroot()
    
    # Define the namespace to simplify searching elements
    ns = {'netex': 'http://www.netex.org.uk/netex'}
    
    # Extract routes data
    routes_data = []
    for route in root.findall('.//netex:Route', ns):
        route_id = route.attrib.get('id')
        route_name = route.find('netex:Name', ns).text
        direction = route.find('netex:DirectionType', ns).text
        
        # Extract points in sequence for each route
        points_in_sequence = []
        for point in route.findall('.//netex:PointOnRoute', ns):
            point_id = point.attrib.get('id')
            order = point.attrib.get('order')
            ref = point.find('netex:RoutePointRef', ns).attrib.get('ref')
            points_in_sequence.append({
                'Point_ID': point_id,
                'Order': order,
                'RoutePointRef': ref
            })
        
        routes_data.append({
            'Route_ID': route_id,
            'Route_Name': route_name,
            'Direction': direction,
            'Points_in_Sequence': points_in_sequence,
            'Private_Code': private_code  # Add private code to routes data
        })

    # Extract timetable and service journey data along with public and private codes
    timetable_data = []
    for journey in root.findall('.//netex:ServiceJourney', ns):
        journey_id = journey.attrib.get('id')
        transport_mode = journey.find('netex:TransportMode', ns).text
        
        # Extract operator, day types, and public/private codes
        operator_ref = journey.find('.//netex:OperatorRef', ns).attrib.get('ref')
        day_type_ref = journey.find('.//netex:DayTypeRef', ns).attrib.get('ref')
        
        # Extract LineRef to find public and private codes
        line_ref = journey.find('.//netex:JourneyPatternRef', ns).attrib.get('ref')
        line = root.find(f".//netex:Line[@id='{line_ref}']", ns)
        
        public_code = line.find('netex:PublicCode', ns).text if line is not None else None
        
        # Extract passing times for each stop in the journey
        for passing_time in journey.findall('.//netex:TimetabledPassingTime', ns):
            stop_ref = passing_time.find('netex:StopPointInJourneyPatternRef', ns).attrib.get('ref')
            arrival_time = passing_time.find('netex:ArrivalTime', ns)
            departure_time = passing_time.find('netex:DepartureTime', ns)
            
            timetable_data.append({
                'Journey_ID': journey_id,
                'TransportMode': transport_mode,
                'OperatorRef': operator_ref,
                'DayTypeRef': day_type_ref,
                'PublicCode': public_code,
                'PrivateCode': private_code,  # Add private code to timetable data
                'StopPointInJourneyPatternRef': stop_ref,
                'ArrivalTime': arrival_time.text if arrival_time is not None else None,
                'DepartureTime': departure_time.text if departure_time is not None else None
            })

    # Create DataFrames
    routes_df = pd.DataFrame(routes_data)
    timetable_df = pd.DataFrame(timetable_data)

    return routes_df, timetable_df

# Main function to read all files starting with 'line'
def process_all_line_files(directory_path):
    all_routes_data = []
    all_timetable_data = []

    # Find all files starting with "line" in the specified directory
    file_pattern = os.path.join(directory_path, 'line*.xml')
    for xml_file in glob.glob(file_pattern):
        print(f"Processing file: {xml_file}")
        
        # Extract private code from the filename (3rd part of the filename)
        private_code = os.path.basename(xml_file).split('_')[2]

        # Extract data from the current XML file, passing the private code
        routes_df, timetable_df = extract_from_xml(xml_file, private_code)
        all_routes_data.append(routes_df)
        all_timetable_data.append(timetable_df)

    # Concatenate all data into single DataFrames
    if all_routes_data:
        final_routes_df = pd.concat(all_routes_data, ignore_index=True)
    else:
        final_routes_df = pd.DataFrame()

    if all_timetable_data:
        final_timetable_df = pd.concat(all_timetable_data, ignore_index=True)
    else:
        final_timetable_df = pd.DataFrame()

    return final_routes_df, final_timetable_df

# Example usage
directory_path = 'sl_data'  # <-- Replace with the actual directory path

# Process all files starting with 'line' in the directory
final_routes_df, final_timetable_df = process_all_line_files(directory_path)

# Display the DataFrames
print(final_routes_df.head())   # Routes DataFrame with private codes
print(final_timetable_df.head()) # Timetable and service journey DataFrame with private codes
# Out:
# Processing file: sl_data/line_1_657_9011001065700000.xml
# Processing file: sl_data/line_1_758_9011001075800000.xml
# Processing file: sl_data/line_1_752_9011001075200000.xml
# Processing file: sl_data/line_1_852_9011001085200000.xml
# Processing file: sl_data/line_1_558_9011001055800000.xml
# Processing file: sl_data/line_1_552_9011001055200000.xml
# Processing file: sl_data/line_1_858_9011001085800000.xml
# Processing file: sl_data/line_1_165_9011001016500000.xml
# Processing file: sl_data/line_1_76_9011001007600000.xml
# Processing file: sl_data/line_1_436_9011001043600000.xml
# Processing file: sl_data/line_1_17_9011001001700000.xml
# Processing file: sl_data/line_8_3_9011008000300000.xml
# Processing file: sl_data/line_8_9_9011008000900000.xml
# Processing file: sl_data/line_1_539_9011001053900000.xml
# Processing file: sl_data/line_1_833_9011001083300000.xml
# Processing file: sl_data/line_1_839_9011001083900000.xml
# Processing file: sl_data/line_1_533_9011001053300000.xml
# Processing file: sl_data/line_1_480_9011001048000000.xml
# Processing file: sl_data/line_1_680_9011001068000000.xml
# Processing file: sl_data/line_1_636_9011001063600000.xml
# Processing file: sl_data/line_1_201_9011001020100000.xml
# Processing file: sl_data/line_1_648_9011001064800000.xml
# Processing file: sl_data/line_1_642_9011001064200000.xml
# Processing file: sl_data/line_1_747_9011001074700000.xml
# Processing file: sl_data/line_1_547_9011001054700000.xml
# Processing file: sl_data/line_1_847_9011001084700000.xml
# Processing file: sl_data/line_1_69_9011001006900000.xml
# Processing file: sl_data/line_1_448_9011001044800000.xml
# Processing file: sl_data/line_1_442_9011001044200000.xml
# Processing file: sl_data/line_1_429_9011001042900000.xml
# Processing file: sl_data/line_1_7_9011001000700000.xml
# Processing file: sl_data/line_1_923_9011001092300000.xml
# Processing file: sl_data/line_1_890_9011001089000000.xml
# Processing file: sl_data/line_1_423_9011001042300000.xml
# Processing file: sl_data/line_1_590_9011001059000000.xml
# Processing file: sl_data/line_8_16_9011008001600000.xml
# Processing file: sl_data/line_1_526_9011001052600000.xml
# Processing file: sl_data/line_1_826_9011001082600000.xml
# Processing file: sl_data/line_1_726_9011001072600000.xml
# Processing file: sl_data/line_1_311_9011001031100000.xml
# Processing file: sl_data/line_1_695_9011001069500000.xml
# Processing file: sl_data/line_1_629_9011001062900000.xml
# Processing file: sl_data/line_1_623_9011001062300000.xml
# Processing file: sl_data/line_1_798_9011001079800000.xml
# Processing file: sl_data/line_1_792_9011001079200000.xml
# Processing file: sl_data/line_1_621_9011001062100000.xml
# Processing file: sl_data/line_1_313_9011001031300000.xml
# Processing file: sl_data/line_1_697_9011001069700000.xml
# Processing file: sl_data/line_1_497_9011001049700000.xml
# Processing file: sl_data/line_8_14_9011008001400000.xml
# Processing file: sl_data/line_1_524_9011001052400000.xml
# Processing file: sl_data/line_1_113_9011001011300000.xml
# Processing file: sl_data/line_1_119_9011001011900000.xml
# Processing file: sl_data/line_1_824_9011001082400000.xml
# Processing file: sl_data/line_1_921_9011001092100000.xml
# Processing file: sl_data/line_1_598_9011001059800000.xml
# Processing file: sl_data/line_1_892_9011001089200000.xml
# Processing file: sl_data/line_1_421_9011001042100000.xml
# Processing file: sl_data/line_1_898_9011001089800000.xml
# Processing file: sl_data/line_1_592_9011001059200000.xml
# Processing file: sl_data/line_1_440_9011001044000000.xml
# Processing file: sl_data/line_1_61_9011001006100000.xml
# Processing file: sl_data/line_1_172_9011001017200000.xml
# Processing file: sl_data/line_1_545_9011001054500000.xml
# Processing file: sl_data/line_1_845_9011001084500000.xml
# Processing file: sl_data/line_1_178_9011001017800000.xml
# Processing file: sl_data/line_1_640_9011001064000000.xml
# Processing file: sl_data/line_1_634_9011001063400000.xml
# Processing file: sl_data/line_1_203_9011001020300000.xml
# Processing file: sl_data/line_1_787_9011001078700000.xml
# Processing file: sl_data/line_1_688_9011001068800000.xml
# Processing file: sl_data/line_1_682_9011001068200000.xml
# Processing file: sl_data/line_1_731_9011001073100000.xml
# Processing file: sl_data/line_1_831_9011001083100000.xml
# Processing file: sl_data/line_1_982_9011001098200000.xml
# Processing file: sl_data/line_1_531_9011001053100000.xml
# Processing file: sl_data/line_1_434_9011001043400000.xml
# Processing file: sl_data/line_1_74_9011001007400000.xml
# Processing file: sl_data/line_1_955_9011001095500000.xml
# Processing file: sl_data/line_1_850_9011001085000000.xml
# Processing file: sl_data/line_1_550_9011001055000000.xml
# Processing file: sl_data/line_1_167_9011001016700000.xml
# Processing file: sl_data/line_1_750_9011001075000000.xml
# Processing file: sl_data/line_1_655_9011001065500000.xml
# Processing file: sl_data/line_1_607_9011001060700000.xml
# Processing file: sl_data/line_1_702_9011001070200000.xml
# Processing file: sl_data/line_1_708_9011001070800000.xml
# Processing file: sl_data/line_1_502_9011001050200000.xml
# Processing file: sl_data/line_1_135_9011001013500000.xml
# Processing file: sl_data/line_1_802_9011001080200000.xml
# Processing file: sl_data/line_1_508_9011001050800000.xml
# Processing file: sl_data/line_1_183_9011001018300000.xml
# Processing file: sl_data/line_1_966_9011001096600000.xml
# Processing file: sl_data/line_2_994_9011002099400000.xml
# Processing file: sl_data/line_1_869_9011001086900000.xml
# Processing file: sl_data/line_1_666_9011001066600000.xml
# Processing file: sl_data/line_1_396_9011001039600000.xml
# Processing file: sl_data/line_1_612_9011001061200000.xml
# Processing file: sl_data/line_1_225_9011001022500000.xml
# Processing file: sl_data/line_1_717_9011001071700000.xml
# Processing file: sl_data/line_1_293_9011001029300000.xml
# Processing file: sl_data/line_1_817_9011001081700000.xml
# Processing file: sl_data/line_1_517_9011001051700000.xml
# Processing file: sl_data/line_1_196_9011001019600000.xml
# Processing file: sl_data/line_1_912_9011001091200000.xml
# Processing file: sl_data/line_1_418_9011001041800000.xml
# Processing file: sl_data/line_1_979_9011001097900000.xml
# Processing file: sl_data/line_1_576_9011001057600000.xml
# Processing file: sl_data/line_1_141_9011001014100000.xml
# Processing file: sl_data/line_1_776_9011001077600000.xml
# Processing file: sl_data/line_1_574_9011001057400000.xml
# Processing file: sl_data/line_1_143_9011001014300000.xml
# Processing file: sl_data/line_1_50_9011001005000000.xml
# Processing file: sl_data/line_1_471_9011001047100000.xml
# Processing file: sl_data/line_1_971_9011001097100000.xml
# Processing file: sl_data/line_1_410_9011001041000000.xml
# Processing file: sl_data/line_1_31_9011001003100000.xml
# Processing file: sl_data/line_1_194_9011001019400000.xml
# Processing file: sl_data/line_1_815_9011001081500000.xml
# Processing file: sl_data/line_8_25_9011008002500000.xml
# Processing file: sl_data/line_1_515_9011001051500000.xml
# Processing file: sl_data/line_1_715_9011001071500000.xml
# Processing file: sl_data/line_1_291_9011001029100000.xml
# Processing file: sl_data/line_1_610_9011001061000000.xml
# Processing file: sl_data/line_1_664_9011001066400000.xml
# Processing file: sl_data/line_1_761_9011001076100000.xml
# Processing file: sl_data/line_1_156_9011001015600000.xml
# Processing file: sl_data/line_1_861_9011001086100000.xml
# Processing file: sl_data/line_1_181_9011001018100000.xml
# Processing file: sl_data/line_1_405_9011001040500000.xml
# Processing file: sl_data/line_8_30_9011008003000000.xml
# Processing file: sl_data/line_1_238_9011001023800000.xml
# Processing file: sl_data/line_1_605_9011001060500000.xml
# Processing file: sl_data/line_1_641_9011001064100000.xml
# Processing file: sl_data/line_1_744_9011001074400000.xml
# Processing file: sl_data/line_1_544_9011001054400000.xml
# Processing file: sl_data/line_1_173_9011001017300000.xml
# Processing file: sl_data/line_1_844_9011001084400000.xml
# Processing file: sl_data/line_1_179_9011001017900000.xml
# Processing file: sl_data/line_1_441_9011001044100000.xml
# Processing file: sl_data/line_1_893_9011001089300000.xml
# Processing file: sl_data/line_1_599_9011001059900000.xml
# Processing file: sl_data/line_1_4_9011001000400000.xml
# Processing file: sl_data/line_1_593_9011001059300000.xml
# Processing file: sl_data/line_1_420_9011001042000000.xml
# Processing file: sl_data/line_1_112_9011001011200000.xml
# Processing file: sl_data/line_1_525_9011001052500000.xml
# Processing file: sl_data/line_1_496_9011001049600000.xml
# Processing file: sl_data/line_1_118_9011001011800000.xml
# Processing file: sl_data/line_1_696_9011001069600000.xml
# Processing file: sl_data/line_1_312_9011001031200000.xml
# Processing file: sl_data/line_1_725_9011001072500000.xml
# Processing file: sl_data/line_1_318_9011001031800000.xml
# Processing file: sl_data/line_1_620_9011001062000000.xml
# Processing file: sl_data/line_1_654_9011001065400000.xml
# Processing file: sl_data/line_1_751_9011001075100000.xml
# Processing file: sl_data/line_5_959_9011005095900000.xml
# Processing file: sl_data/line_1_75_9011001007500000.xml
# Processing file: sl_data/line_1_14_9011001001400000.xml
# Processing file: sl_data/line_1_435_9011001043500000.xml
# Processing file: sl_data/line_1_983_9011001098300000.xml
# Processing file: sl_data/line_1_489_9011001048900000.xml
# Processing file: sl_data/line_1_830_9011001083000000.xml
# Processing file: sl_data/line_1_689_9011001068900000.xml
# Processing file: sl_data/line_1_683_9011001068300000.xml
# Processing file: sl_data/line_1_786_9011001078600000.xml
# Processing file: sl_data/line_1_635_9011001063500000.xml
# Processing file: sl_data/line_1_784_9011001078400000.xml
# Processing file: sl_data/line_1_637_9011001063700000.xml
# Processing file: sl_data/line_1_738_9011001073800000.xml
# Processing file: sl_data/line_1_305_9011001030500000.xml
# Processing file: sl_data/line_1_681_9011001068100000.xml
# Processing file: sl_data/line_1_981_9011001098100000.xml
# Processing file: sl_data/line_1_832_9011001083200000.xml
# Processing file: sl_data/line_1_538_9011001053800000.xml
# Processing file: sl_data/line_1_532_9011001053200000.xml
# Processing file: sl_data/line_1_838_9011001083800000.xml
# Processing file: sl_data/line_8_2_9011008000200000.xml
# Processing file: sl_data/line_1_437_9011001043700000.xml
# Processing file: sl_data/line_1_584_9011001058400000.xml
# Processing file: sl_data/line_8_8_9011008000800000.xml
# Processing file: sl_data/line_1_77_9011001007700000.xml
# Processing file: sl_data/line_5_951_9011005095100000.xml
# Processing file: sl_data/line_1_559_9011001055900000.xml
# Processing file: sl_data/line_1_164_9011001016400000.xml
# Processing file: sl_data/line_1_553_9011001055300000.xml
# Processing file: sl_data/line_1_759_9011001075900000.xml
# Processing file: sl_data/line_1_753_9011001075300000.xml
# Processing file: sl_data/line_1_656_9011001065600000.xml
# Processing file: sl_data/line_1_628_9011001062800000.xml
# Processing file: sl_data/line_1_622_9011001062200000.xml
# Processing file: sl_data/line_1_791_9011001079100000.xml
# Processing file: sl_data/line_1_694_9011001069400000.xml
# Processing file: sl_data/line_1_727_9011001072700000.xml
# Processing file: sl_data/line_1_527_9011001052700000.xml
# Processing file: sl_data/line_8_17_9011008001700000.xml
# Processing file: sl_data/line_1_827_9011001082700000.xml
# Processing file: sl_data/line_1_6_9011001000600000.xml
# Processing file: sl_data/line_1_428_9011001042800000.xml
# Processing file: sl_data/line_1_591_9011001059100000.xml
# Processing file: sl_data/line_1_422_9011001042200000.xml
# Processing file: sl_data/line_1_449_9011001044900000.xml
# Processing file: sl_data/line_1_443_9011001044300000.xml
# Processing file: sl_data/line_1_546_9011001054600000.xml
# Processing file: sl_data/line_1_846_9011001084600000.xml
# Processing file: sl_data/line_1_649_9011001064900000.xml
# Processing file: sl_data/line_1_643_9011001064300000.xml
# Processing file: sl_data/line_1_611_9011001061100000.xml
# Processing file: sl_data/line_1_714_9011001071400000.xml
# Processing file: sl_data/line_1_323_9011001032300000.xml
# Processing file: sl_data/line_1_129_9011001012900000.xml
# Processing file: sl_data/line_1_814_9011001081400000.xml
# Processing file: sl_data/line_1_514_9011001051400000.xml
# Processing file: sl_data/line_1_195_9011001019500000.xml
# Processing file: sl_data/line_1_30_9011001003000000.xml
# Processing file: sl_data/line_1_411_9011001041100000.xml
# Processing file: sl_data/line_1_875_9011001087500000.xml
# Processing file: sl_data/line_1_142_9011001014200000.xml
# Processing file: sl_data/line_1_575_9011001057500000.xml
# Processing file: sl_data/line_1_670_9011001067000000.xml
# Processing file: sl_data/line_1_604_9011001060400000.xml
# Processing file: sl_data/line_1_93_9011001009300000.xml
# Processing file: sl_data/line_8_31_9011008003100000.xml
# Processing file: sl_data/line_1_501_9011001050100000.xml
# Processing file: sl_data/line_1_801_9011001080100000.xml
# Processing file: sl_data/line_5_903_9011005090300000.xml
# Processing file: sl_data/line_5_909_9011005090900000.xml
# Processing file: sl_data/line_1_180_9011001018000000.xml
# Processing file: sl_data/line_1_44_9011001004400000.xml
# Processing file: sl_data/line_1_465_9011001046500000.xml
# Processing file: sl_data/line_1_560_9011001056000000.xml
# Processing file: sl_data/line_1_157_9011001015700000.xml
# Processing file: sl_data/line_1_665_9011001066500000.xml
# Processing file: sl_data/line_1_667_9011001066700000.xml
# Processing file: sl_data/line_1_562_9011001056200000.xml
# Processing file: sl_data/line_1_155_9011001015500000.xml
# Processing file: sl_data/line_1_862_9011001086200000.xml
# Processing file: sl_data/line_1_568_9011001056800000.xml
# Processing file: sl_data/line_1_467_9011001046700000.xml
# Processing file: sl_data/line_2_995_9011002099500000.xml
# Processing file: sl_data/line_5_901_9011005090100000.xml
# Processing file: sl_data/line_1_188_9011001018800000.xml
# Processing file: sl_data/line_1_27_9011001002700000.xml
# Processing file: sl_data/line_1_91_9011001009100000.xml
# Processing file: sl_data/line_1_134_9011001013400000.xml
# Processing file: sl_data/line_1_809_9011001080900000.xml
# Processing file: sl_data/line_1_503_9011001050300000.xml
# Processing file: sl_data/line_1_509_9011001050900000.xml
# Processing file: sl_data/line_1_803_9011001080300000.xml
# Processing file: sl_data/line_1_703_9011001070300000.xml
# Processing file: sl_data/line_1_709_9011001070900000.xml
# Processing file: sl_data/line_1_606_9011001060600000.xml
# Processing file: sl_data/line_1_777_9011001077700000.xml
# Processing file: sl_data/line_1_577_9011001057700000.xml
# Processing file: sl_data/line_1_978_9011001097800000.xml
# Processing file: sl_data/line_1_53_9011001005300000.xml
# Processing file: sl_data/line_1_197_9011001019700000.xml
# Processing file: sl_data/line_1_413_9011001041300000.xml
# Processing file: sl_data/line_5_914_9011005091400000.xml
# Processing file: sl_data/line_1_816_9011001081600000.xml
# Processing file: sl_data/line_1_516_9011001051600000.xml
# Processing file: sl_data/line_8_26_9011008002600000.xml
# Processing file: sl_data/line_1_84_9011001008400000.xml
# Processing file: sl_data/line_1_716_9011001071600000.xml
# Processing file: sl_data/line_1_613_9011001061300000.xml
# Processing file: sl_data/line_1_619_9011001061900000.xml
# Processing file: sl_data/line_1_627_9011001062700000.xml
# Processing file: sl_data/line_1_794_9011001079400000.xml
# Processing file: sl_data/line_1_691_9011001069100000.xml
# Processing file: sl_data/line_1_315_9011001031500000.xml
# Processing file: sl_data/line_1_822_9011001082200000.xml
# Processing file: sl_data/line_1_528_9011001052800000.xml
# Processing file: sl_data/line_1_522_9011001052200000.xml
# Processing file: sl_data/line_1_115_9011001011500000.xml
# Processing file: sl_data/line_1_828_9011001082800000.xml
# Processing file: sl_data/line_1_491_9011001049100000.xml
# Processing file: sl_data/line_8_12_9011008001200000.xml
# Processing file: sl_data/line_1_3_9011001000300000.xml
# Processing file: sl_data/line_1_446_9011001044600000.xml
# Processing file: sl_data/line_1_67_9011001006700000.xml
# Processing file: sl_data/line_1_843_9011001084300000.xml
# Processing file: sl_data/line_1_849_9011001084900000.xml
# Processing file: sl_data/line_1_543_9011001054300000.xml
# Processing file: sl_data/line_1_749_9011001074900000.xml
# Processing file: sl_data/line_1_646_9011001064600000.xml
# Processing file: sl_data/line_1_638_9011001063800000.xml
# Processing file: sl_data/line_1_781_9011001078100000.xml
# Processing file: sl_data/line_1_632_9011001063200000.xml
# Processing file: sl_data/line_1_205_9011001020500000.xml
# Processing file: sl_data/line_1_737_9011001073700000.xml
# Processing file: sl_data/line_1_684_9011001068400000.xml
# Processing file: sl_data/line_1_537_9011001053700000.xml
# Processing file: sl_data/line_1_837_9011001083700000.xml
# Processing file: sl_data/line_1_19_9011001001900000.xml
# Processing file: sl_data/line_1_438_9011001043800000.xml
# Processing file: sl_data/line_1_432_9011001043200000.xml
# Processing file: sl_data/line_1_13_9011001001300000.xml
# Processing file: sl_data/line_1_581_9011001058100000.xml
# Processing file: sl_data/line_1_953_9011001095300000.xml
# Processing file: sl_data/line_1_72_9011001007200000.xml
# Processing file: sl_data/line_1_556_9011001055600000.xml
# Processing file: sl_data/line_1_161_9011001016100000.xml
# Processing file: sl_data/line_1_856_9011001085600000.xml
# Processing file: sl_data/line_1_756_9011001075600000.xml
# Processing file: sl_data/line_1_653_9011001065300000.xml
# Processing file: sl_data/line_1_651_9011001065100000.xml
# Processing file: sl_data/line_1_754_9011001075400000.xml
# Processing file: sl_data/line_1_163_9011001016300000.xml
# Processing file: sl_data/line_1_854_9011001085400000.xml
# Processing file: sl_data/line_1_930_9011001093000000.xml
# Processing file: sl_data/line_1_589_9011001058900000.xml
# Processing file: sl_data/line_1_430_9011001043000000.xml
# Processing file: sl_data/line_8_5_9011008000500000.xml
# Processing file: sl_data/line_1_11_9011001001100000.xml
# Processing file: sl_data/line_1_583_9011001058300000.xml
# Processing file: sl_data/line_1_889_9011001088900000.xml
# Processing file: sl_data/line_1_535_9011001053500000.xml
# Processing file: sl_data/line_1_986_9011001098600000.xml
# Processing file: sl_data/line_1_835_9011001083500000.xml
# Processing file: sl_data/line_1_302_9011001030200000.xml
# Processing file: sl_data/line_1_789_9011001078900000.xml
# Processing file: sl_data/line_1_783_9011001078300000.xml
# Processing file: sl_data/line_1_630_9011001063000000.xml
# Processing file: sl_data/line_1_644_9011001064400000.xml
# Processing file: sl_data/line_1_176_9011001017600000.xml
# Processing file: sl_data/line_1_541_9011001054100000.xml
# Processing file: sl_data/line_1_444_9011001044400000.xml
# Processing file: sl_data/line_1_65_9011001006500000.xml
# Processing file: sl_data/line_1_425_9011001042500000.xml
# Processing file: sl_data/line_1_1_9011001000100000.xml
# Processing file: sl_data/line_1_925_9011001092500000.xml
# Processing file: sl_data/line_1_820_9011001082000000.xml
# Processing file: sl_data/line_1_520_9011001052000000.xml
# Processing file: sl_data/line_1_117_9011001011700000.xml
# Processing file: sl_data/line_8_10_9011008001000000.xml
# Processing file: sl_data/line_1_699_9011001069900000.xml
# Processing file: sl_data/line_1_317_9011001031700000.xml
# Processing file: sl_data/line_1_212_9011001021200000.xml
# Processing file: sl_data/line_1_625_9011001062500000.xml
# Processing file: sl_data/line_1_796_9011001079600000.xml
# Processing file: sl_data/line_1_677_9011001067700000.xml
# Processing file: sl_data/line_1_778_9011001077800000.xml
# Processing file: sl_data/line_1_56_9011001005600000.xml
# Processing file: sl_data/line_1_198_9011001019800000.xml
# Processing file: sl_data/line_1_192_9011001019200000.xml
# Processing file: sl_data/line_1_416_9011001041600000.xml
# Processing file: sl_data/line_1_124_9011001012400000.xml
# Processing file: sl_data/line_1_819_9011001081900000.xml
# Processing file: sl_data/line_1_513_9011001051300000.xml
# Processing file: sl_data/line_8_23_9011008002300000.xml
# Processing file: sl_data/line_1_813_9011001081300000.xml
# Processing file: sl_data/line_8_29_9011008002900000.xml
# Processing file: sl_data/line_1_713_9011001071300000.xml
# Processing file: sl_data/line_1_719_9011001071900000.xml
# Processing file: sl_data/line_1_616_9011001061600000.xml
# Processing file: sl_data/line_1_662_9011001066200000.xml
# Processing file: sl_data/line_1_668_9011001066800000.xml
# Processing file: sl_data/line_1_350_9011001035000000.xml
# Processing file: sl_data/line_1_567_9011001056700000.xml
# Processing file: sl_data/line_1_462_9011001046200000.xml
# Processing file: sl_data/line_1_968_9011001096800000.xml
# Processing file: sl_data/line_1_43_9011001004300000.xml
# Processing file: sl_data/line_2_990_9011002099000000.xml
# Processing file: sl_data/line_1_468_9011001046800000.xml
# Processing file: sl_data/line_1_409_9011001040900000.xml
# Processing file: sl_data/line_5_904_9011005090400000.xml
# Processing file: sl_data/line_1_28_9011001002800000.xml
# Processing file: sl_data/line_1_806_9011001080600000.xml
# Processing file: sl_data/line_1_94_9011001009400000.xml
# Processing file: sl_data/line_1_506_9011001050600000.xml
# Processing file: sl_data/line_1_706_9011001070600000.xml
# Processing file: sl_data/line_1_282_9011001028200000.xml
# Processing file: sl_data/line_1_609_9011001060900000.xml
# Processing file: sl_data/line_1_601_9011001060100000.xml
# Processing file: sl_data/line_1_704_9011001070400000.xml
# Processing file: sl_data/line_1_333_9011001033300000.xml
# Processing file: sl_data/line_1_804_9011001080400000.xml
# Processing file: sl_data/line_1_96_9011001009600000.xml
# Processing file: sl_data/line_1_504_9011001050400000.xml
# Processing file: sl_data/line_1_133_9011001013300000.xml
# Processing file: sl_data/line_1_401_9011001040100000.xml
# Processing file: sl_data/line_1_185_9011001018500000.xml
# Processing file: sl_data/line_5_906_9011005090600000.xml
# Processing file: sl_data/line_1_41_9011001004100000.xml
# Processing file: sl_data/line_1_865_9011001086500000.xml
# Processing file: sl_data/line_1_158_9011001015800000.xml
# Processing file: sl_data/line_1_152_9011001015200000.xml
# Processing file: sl_data/line_1_660_9011001066000000.xml
# Processing file: sl_data/line_1_614_9011001061400000.xml
# Processing file: sl_data/line_1_711_9011001071100000.xml
# Processing file: sl_data/line_1_511_9011001051100000.xml
# Processing file: sl_data/line_1_83_9011001008300000.xml
# Processing file: sl_data/line_8_21_9011008002100000.xml
# Processing file: sl_data/line_1_89_9011001008900000.xml
# Processing file: sl_data/line_1_190_9011001019000000.xml
# Processing file: sl_data/line_1_414_9011001041400000.xml
# Processing file: sl_data/line_5_972_9011005097200000.xml
# Processing file: sl_data/line_1_54_9011001005400000.xml
# Processing file: sl_data/line_1_570_9011001057000000.xml
# Processing file: sl_data/line_1_147_9011001014700000.xml
# Processing file: sl_data/line_1_788_9011001078800000.xml
# Processing file: sl_data/line_1_206_9011001020600000.xml
# Processing file: sl_data/line_1_631_9011001063100000.xml
# Processing file: sl_data/line_1_782_9011001078200000.xml
# Processing file: sl_data/line_1_687_9011001068700000.xml
# Processing file: sl_data/line_1_303_9011001030300000.xml
# Processing file: sl_data/line_1_309_9011001030900000.xml
# Processing file: sl_data/line_1_534_9011001053400000.xml
# Processing file: sl_data/line_1_834_9011001083400000.xml
# Processing file: sl_data/line_1_987_9011001098700000.xml
# Processing file: sl_data/line_1_931_9011001093100000.xml
# Processing file: sl_data/line_1_582_9011001058200000.xml
# Processing file: sl_data/line_8_4_9011008000400000.xml
# Processing file: sl_data/line_1_10_9011001001000000.xml
# Processing file: sl_data/line_1_71_9011001007100000.xml
# Processing file: sl_data/line_1_555_9011001055500000.xml
# Processing file: sl_data/line_1_650_9011001065000000.xml
# Processing file: sl_data/line_1_797_9011001079700000.xml
# Processing file: sl_data/line_1_624_9011001062400000.xml
# Processing file: sl_data/line_1_698_9011001069800000.xml
# Processing file: sl_data/line_1_316_9011001031600000.xml
# Processing file: sl_data/line_1_721_9011001072100000.xml
# Processing file: sl_data/line_1_821_9011001082100000.xml
# Processing file: sl_data/line_8_11_9011008001100000.xml
# Processing file: sl_data/line_1_492_9011001049200000.xml
# Processing file: sl_data/line_1_116_9011001011600000.xml
# Processing file: sl_data/line_1_424_9011001042400000.xml
# Processing file: sl_data/line_1_597_9011001059700000.xml
# Processing file: sl_data/line_1_445_9011001044500000.xml
# Processing file: sl_data/line_1_840_9011001084000000.xml
# Processing file: sl_data/line_1_540_9011001054000000.xml
# Processing file: sl_data/line_1_177_9011001017700000.xml
# Processing file: sl_data/line_1_740_9011001074000000.xml
# Processing file: sl_data/line_1_645_9011001064500000.xml
# Processing file: sl_data/line_1_647_9011001064700000.xml
# Processing file: sl_data/line_1_748_9011001074800000.xml
# Processing file: sl_data/line_1_742_9011001074200000.xml
# Processing file: sl_data/line_1_842_9011001084200000.xml
# Processing file: sl_data/line_1_548_9011001054800000.xml
# Processing file: sl_data/line_1_542_9011001054200000.xml
# Processing file: sl_data/line_1_848_9011001084800000.xml
# Processing file: sl_data/line_1_175_9011001017500000.xml
# Processing file: sl_data/line_1_66_9011001006600000.xml
# Processing file: sl_data/line_1_447_9011001044700000.xml
# Processing file: sl_data/line_1_426_9011001042600000.xml
# Processing file: sl_data/line_1_595_9011001059500000.xml
# Processing file: sl_data/line_1_926_9011001092600000.xml
# Processing file: sl_data/line_1_2_9011001000200000.xml
# Processing file: sl_data/line_8_19_9011008001900000.xml
# Processing file: sl_data/line_1_529_9011001052900000.xml
# Processing file: sl_data/line_1_823_9011001082300000.xml
# Processing file: sl_data/line_8_13_9011008001300000.xml
# Processing file: sl_data/line_1_114_9011001011400000.xml
# Processing file: sl_data/line_1_829_9011001082900000.xml
# Processing file: sl_data/line_1_523_9011001052300000.xml
# Processing file: sl_data/line_1_729_9011001072900000.xml
# Processing file: sl_data/line_1_723_9011001072300000.xml
# Processing file: sl_data/line_1_690_9011001069000000.xml
# Processing file: sl_data/line_1_795_9011001079500000.xml
# Processing file: sl_data/line_1_626_9011001062600000.xml
# Processing file: sl_data/line_1_211_9011001021100000.xml
# Processing file: sl_data/line_1_658_9011001065800000.xml
# Processing file: sl_data/line_1_652_9011001065200000.xml
# Processing file: sl_data/line_1_160_9011001016000000.xml
# Processing file: sl_data/line_1_557_9011001055700000.xml
# Processing file: sl_data/line_1_952_9011001095200000.xml
# Processing file: sl_data/line_1_458_9011001045800000.xml
# Processing file: sl_data/line_1_958_9011001095800000.xml
# Processing file: sl_data/line_1_439_9011001043900000.xml
# Processing file: sl_data/line_1_18_9011001001800000.xml
# Processing file: sl_data/line_1_580_9011001058000000.xml
# Processing file: sl_data/line_1_12_9011001001200000.xml
# Processing file: sl_data/line_1_433_9011001043300000.xml
# Processing file: sl_data/line_1_536_9011001053600000.xml
# Processing file: sl_data/line_1_836_9011001083600000.xml
# Processing file: sl_data/line_1_685_9011001068500000.xml
# Processing file: sl_data/line_1_301_9011001030100000.xml
# Processing file: sl_data/line_1_639_9011001063900000.xml
# Processing file: sl_data/line_1_204_9011001020400000.xml
# Processing file: sl_data/line_1_633_9011001063300000.xml
# Processing file: sl_data/line_1_780_9011001078000000.xml
# Processing file: sl_data/line_1_661_9011001066100000.xml
# Processing file: sl_data/line_1_159_9011001015900000.xml
# Processing file: sl_data/line_1_564_9011001056400000.xml
# Processing file: sl_data/line_2_993_9011002099300000.xml
# Processing file: sl_data/line_1_40_9011001004000000.xml
# Processing file: sl_data/line_1_461_9011001046100000.xml
# Processing file: sl_data/line_1_961_9011001096100000.xml
# Processing file: sl_data/line_1_184_9011001018400000.xml
# Processing file: sl_data/line_1_21_9011001002100000.xml
# Processing file: sl_data/line_5_907_9011005090700000.xml
# Processing file: sl_data/line_1_805_9011001080500000.xml
# Processing file: sl_data/line_1_505_9011001050500000.xml
# Processing file: sl_data/line_1_705_9011001070500000.xml
# Processing file: sl_data/line_1_571_9011001057100000.xml
# Processing file: sl_data/line_1_474_9011001047400000.xml
# Processing file: sl_data/line_1_55_9011001005500000.xml
# Processing file: sl_data/line_1_191_9011001019100000.xml
# Processing file: sl_data/line_1_82_9011001008200000.xml
# Processing file: sl_data/line_8_20_9011008002000000.xml
# Processing file: sl_data/line_1_127_9011001012700000.xml
# Processing file: sl_data/line_1_810_9011001081000000.xml
# Processing file: sl_data/line_1_710_9011001071000000.xml
# Processing file: sl_data/line_1_222_9011001022200000.xml
# Processing file: sl_data/line_1_615_9011001061500000.xml
# Processing file: sl_data/line_1_617_9011001061700000.xml
# Processing file: sl_data/line_1_712_9011001071200000.xml
# Processing file: sl_data/line_1_325_9011001032500000.xml
# Processing file: sl_data/line_1_718_9011001071800000.xml
# Processing file: sl_data/line_1_80_9011001008000000.xml
# Processing file: sl_data/line_8_22_9011008002200000.xml
# Processing file: sl_data/line_1_512_9011001051200000.xml
# Processing file: sl_data/line_1_818_9011001081800000.xml
# Processing file: sl_data/line_8_28_9011008002800000.xml
# Processing file: sl_data/line_1_812_9011001081200000.xml
# Processing file: sl_data/line_1_518_9011001051800000.xml
# Processing file: sl_data/line_1_199_9011001019900000.xml
# Processing file: sl_data/line_1_417_9011001041700000.xml
# Processing file: sl_data/line_1_193_9011001019300000.xml
# Processing file: sl_data/line_5_971_9011005097100000.xml
# Processing file: sl_data/line_1_57_9011001005700000.xml
# Processing file: sl_data/line_1_144_9011001014400000.xml
# Processing file: sl_data/line_1_573_9011001057300000.xml
# Processing file: sl_data/line_1_579_9011001057900000.xml
# Processing file: sl_data/line_1_873_9011001087300000.xml
# Processing file: sl_data/line_1_779_9011001077900000.xml
# Processing file: sl_data/line_1_676_9011001067600000.xml
# Processing file: sl_data/line_1_602_9011001060200000.xml
# Processing file: sl_data/line_1_608_9011001060800000.xml
# Processing file: sl_data/line_1_707_9011001070700000.xml
# Processing file: sl_data/line_1_807_9011001080700000.xml
# Processing file: sl_data/line_6_941_9011006094100000.xml
# Processing file: sl_data/line_1_507_9011001050700000.xml
# Processing file: sl_data/line_1_402_9011001040200000.xml
# Processing file: sl_data/line_1_908_9011001090800000.xml
# Processing file: sl_data/line_1_29_9011001002900000.xml
# Processing file: sl_data/line_1_42_9011001004200000.xml
# Processing file: sl_data/line_1_969_9011001096900000.xml
# Processing file: sl_data/line_1_463_9011001046300000.xml
# Processing file: sl_data/line_1_469_9011001046900000.xml
# Processing file: sl_data/line_1_48_9011001004800000.xml
# Processing file: sl_data/line_1_663_9011001066300000.xml
# Processing file: sl_data/line_1_669_9011001066900000.xml
#                          Route_ID       Route_Name Direction  \
# 0  SE:001:Route:14010000668408490         Vigelsjö  outbound
# 1  SE:001:Route:14010000668408521         Vigelsjö  outbound
# 2  SE:001:Route:14010000664752659         Vigelsjö  outbound
# 3  SE:001:Route:14010000664752559         Vigelsjö  outbound
# 4  SE:001:Route:14010000668408439  Campus Roslagen   inbound
#
#                                   Points_in_Sequence Private_Code
# 0  [{'Point_ID': 'SE:001:PointOnRoute:14010000668...          657
# 1  [{'Point_ID': 'SE:001:PointOnRoute:14010000668...          657
# 2  [{'Point_ID': 'SE:001:PointOnRoute:14010000664...          657
# 3  [{'Point_ID': 'SE:001:PointOnRoute:14010000664...          657
# 4  [{'Point_ID': 'SE:001:PointOnRoute:14010000668...          657
#                                 Journey_ID TransportMode  \
# 0  SE:001:ServiceJourney:14010000666428652           bus
# 1  SE:001:ServiceJourney:14010000666428652           bus
# 2  SE:001:ServiceJourney:14010000666428652           bus
# 3  SE:001:ServiceJourney:14010000666428652           bus
# 4  SE:001:ServiceJourney:14010000666428652           bus
#
#                         OperatorRef  \
# 0  SE:001:Operator:9013001004500000
# 1  SE:001:Operator:9013001004500000
# 2  SE:001:Operator:9013001004500000
# 3  SE:001:Operator:9013001004500000
# 4  SE:001:Operator:9013001004500000
#
#                                         DayTypeRef PublicCode PrivateCode  \
# 0  SE:001:DayType:dfivmm59qm8phnc2c6bahh5tkhnp70hp       None         657
# 1  SE:001:DayType:dfivmm59qm8phnc2c6bahh5tkhnp70hp       None         657
# 2  SE:001:DayType:dfivmm59qm8phnc2c6bahh5tkhnp70hp       None         657
# 3  SE:001:DayType:dfivmm59qm8phnc2c6bahh5tkhnp70hp       None         657
# 4  SE:001:DayType:dfivmm59qm8phnc2c6bahh5tkhnp70hp       None         657
#
#                         StopPointInJourneyPatternRef ArrivalTime DepartureTime
# 0  SE:001:StopPointInJourneyPattern:1401941000016...        None      06:09:00
# 1  SE:001:StopPointInJourneyPattern:1401941000016...    06:09:30      06:09:30
# 2  SE:001:StopPointInJourneyPattern:1401941000016...    06:10:06      06:10:06
# 3  SE:001:StopPointInJourneyPattern:1401941000016...    06:11:06      06:11:06
# 4  SE:001:StopPointInJourneyPattern:1401941000016...    06:11:48      06:11:48

# %%
final_routes_df['Route_ID'] = final_routes_df['Route_ID'].str.split(':').str[-1]

# %%
# Assuming final_routes_df is your DataFrame

# Expand Points_in_Sequence so that each element of the list becomes a separate row
# Reset the index to avoid reindexing issues
points_expanded = final_routes_df.explode('Points_in_Sequence').reset_index(drop=True)

# Check if Points_in_Sequence has valid data before proceeding
if points_expanded['Points_in_Sequence'].notnull().all():
    # Convert each dictionary in Points_in_Sequence into separate columns
    points_expanded = pd.concat([
        points_expanded.drop(columns=['Points_in_Sequence']),  # Drop original column
        pd.json_normalize(points_expanded['Points_in_Sequence'])  # Normalize nested data
    ], axis=1)

    # Rename the new columns (optional, for clarity)
    points_expanded.rename(columns={
        'Point_ID': 'Point_ID',
        'Order': 'Order',
        'RoutePointRef': 'RoutePointRef'
    }, inplace=True)

    # Display the expanded DataFrame
    print(points_expanded.head())
else:
    print("Some rows in 'Points_in_Sequence' have null values.")
# Out:
#             Route_ID Route_Name Direction Private_Code  \
# 0  14010000668408490   Vigelsjö  outbound          657
# 1  14010000668408490   Vigelsjö  outbound          657
# 2  14010000668408490   Vigelsjö  outbound          657
# 3  14010000668408490   Vigelsjö  outbound          657
# 4  14010000668408490   Vigelsjö  outbound          657
#
#                                 Point_ID Order  \
# 0  SE:001:PointOnRoute:14010000668408495     1
# 1  SE:001:PointOnRoute:14010000668408496     2
# 2  SE:001:PointOnRoute:14010000668408497     3
# 3  SE:001:PointOnRoute:14010000668408498     4
# 4  SE:001:PointOnRoute:14010000668408499     5
#
#                         RoutePointRef
# 0  SE:001:RoutePoint:9022001064146002
# 1  SE:001:RoutePoint:9022001062571002
# 2  SE:001:RoutePoint:9022001065046001
# 3  SE:001:RoutePoint:9022001065042001
# 4  SE:001:RoutePoint:9022001064478003

# %%
points_expanded['Point_ID'] = points_expanded['Point_ID'].str.split(':').str[-1]

# Extract numeric part from RoutePointRef
points_expanded['RoutePointRef'] = points_expanded['RoutePointRef'].str.split(':').str[-1]

# %%
 points_expanded[points_expanded['RoutePointRef'] == '9021001000814000']
# Out:
# Empty DataFrame
# Columns: [Route_ID, Route_Name, Direction, Private_Code, Point_ID, Order, RoutePointRef]
# Index: []

# %%
final_timetable_df['Journey_ID'] = final_timetable_df['Journey_ID'].str.split(':').str[-1]
final_timetable_df['OperatorRef'] = final_timetable_df['OperatorRef'].str.split(':').str[-1]
final_timetable_df['DayTypeRef'] = final_timetable_df['DayTypeRef'].str.split(':').str[-1]
final_timetable_df['StopPointInJourneyPatternRef'] = final_timetable_df['StopPointInJourneyPatternRef'].str.split(':').str[-1]

# %%
points_expanded
# Out:
#                 Journey_ID TransportMode       OperatorRef  \
# 0        14010000666428652           bus  9013001004500000
# 1        14010000666428652           bus  9013001004500000
# 2        14010000666428652           bus  9013001004500000
# 3        14010000666428652           bus  9013001004500000
# 4        14010000666428652           bus  9013001004500000
# ...                    ...           ...               ...
# 1312298  14010000665301478           bus  9013001004500000
# 1312299  14010000665301478           bus  9013001004500000
# 1312300  14010000665301478           bus  9013001004500000
# 1312301  14010000665301478           bus  9013001004500000
# 1312302  14010000665301478           bus  9013001004500000
#
#                                DayTypeRef PublicCode PrivateCode  \
# 0        dfivmm59qm8phnc2c6bahh5tkhnp70hp       None         657
# 1        dfivmm59qm8phnc2c6bahh5tkhnp70hp       None         657
# 2        dfivmm59qm8phnc2c6bahh5tkhnp70hp       None         657
# 3        dfivmm59qm8phnc2c6bahh5tkhnp70hp       None         657
# 4        dfivmm59qm8phnc2c6bahh5tkhnp70hp       None         657
# ...                                   ...        ...         ...
# 1312298  bncpagqso7dvr0jmc2o233d3een6g00p       None         669
# 1312299  bncpagqso7dvr0jmc2o233d3een6g00p       None         669
# 1312300  bncpagqso7dvr0jmc2o233d3een6g00p       None         669
# 1312301  bncpagqso7dvr0jmc2o233d3een6g00p       None         669
# 1312302  bncpagqso7dvr0jmc2o233d3een6g00p       None         669
#
#                 StopPointInJourneyPatternRef ArrivalTime DepartureTime
# 0        14019410000161291_14010000664752564        None      06:09:00
# 1        14019410000161291_14010000664752565    06:09:30      06:09:30
# 2        14019410000161291_14010000664752566    06:10:06      06:10:06
# 3        14019410000161291_14010000664752567    06:11:06      06:11:06
# 4        14019410000161291_14010000664752568    06:11:48      06:11:48
# ...                                      ...         ...           ...
# 1312298  14019410000142739_14010000621141281    09:23:00      09:23:00
# 1312299  14019410000142739_14010000621141282    09:23:00      09:23:00
# 1312300  14019410000142739_14010000621141283    09:23:00      09:23:00
# 1312301  14019410000142739_14010000621141284    09:23:00      09:23:00
# 1312302  14019410000142739_14010000621141285    09:45:00          None
#
# [1312303 rows x 9 columns]

# %%
### Extract stop data 
from lxml import etree

# Load the NeTEx file
with open('sl_data/_stops.xml', 'rb') as file:
    tree = etree.parse(file)

# Define namespaces (if applicable)



namespaces = {
    'netex': 'http://www.netex.org.uk/netex',
    'gml': 'http://www.opengis.net/gml/3.2',
    'siri': 'http://www.siri.org.uk/siri',
    'sam': 'http://www.samtrafiken.se/netex'
}

group_of_stop_places = tree.xpath('//netex:GroupOfStopPlaces', namespaces=namespaces)

stops = []

for group in group_of_stop_places:
    # Use safe retrieval for each element
    name_elem = group.find('netex:Name', namespaces=namespaces)
    description_elem = group.find('netex:Description', namespaces=namespaces)
    private_code_elem = group.find('netex:PrivateCode', namespaces=namespaces)
    latitude_elem = group.find('netex:Centroid/netex:Location/netex:Latitude', namespaces=namespaces)
    longitude_elem = group.find('netex:Centroid/netex:Location/netex:Longitude', namespaces=namespaces)

    group_info = {
        'Group ID': group.get('id'),
        'Name': name_elem.text if name_elem is not None else '',
        'Description': description_elem.text if description_elem is not None else '',
        'Private Code': private_code_elem.text if private_code_elem is not None else '',
        'Latitude': latitude_elem.text if latitude_elem is not None else '',
        'Longitude': longitude_elem.text if longitude_elem is not None else '',
    }
    
    # Append the group info to the data list
    stops.append(group_info)

# Create a DataFrame from the extracted data
stops_df = pd.DataFrame(stops)

# %%
stops_df['Group ID'] = stops_df['Group ID'].str.split(':').str[-1]

# %%
 stops_df[stops_df['Group ID'] == '9091001000000102']
# Out:
#            Group ID      Name Description Private Code   Latitude  Longitude
# 0  9091001000000102  Styrsvik     Runmarö          102  59.280266  18.731378

# %%
from lxml import etree
import pandas as pd

# Load the NeTEx file
with open('sl_data/_stops.xml', 'rb') as file:
    tree = etree.parse(file)

# Define namespaces (if applicable)
namespaces = {
    'netex': 'http://www.netex.org.uk/netex',
    'gml': 'http://www.opengis.net/gml/3.2',
    'siri': 'http://www.siri.org.uk/siri',
    'sam': 'http://www.samtrafiken.se/netex'
}

# Extract all StopPlace elements
stop_places = tree.xpath('//netex:StopPlace', namespaces=namespaces)

# Initialize a list to store stop and quay data
stops = []

for stop_place in stop_places:
    # Extract StopPlace details
    stop_place_id = stop_place.get('id')
    name_elem = stop_place.find('netex:Name', namespaces=namespaces)
    private_code_elem = stop_place.find('netex:PrivateCode', namespaces=namespaces)
    latitude_elem = stop_place.find('netex:Centroid/netex:Location/netex:Latitude', namespaces=namespaces)
    longitude_elem = stop_place.find('netex:Centroid/netex:Location/netex:Longitude', namespaces=namespaces)

    # Create a dictionary for StopPlace info
    stop_info = {
        'StopPlace ID': stop_place_id,
        'StopPlace Name': name_elem.text if name_elem is not None else '',
        'StopPlace Private Code': private_code_elem.text if private_code_elem is not None else '',
        'StopPlace Latitude': latitude_elem.text if latitude_elem is not None else '',
        'StopPlace Longitude': longitude_elem.text if longitude_elem is not None else ''
    }

    # Now check for any Quays within this StopPlace
    quays = stop_place.findall('.//netex:Quay', namespaces=namespaces)
    if quays:
        for quay in quays:
            # Extract Quay details
            quay_id = quay.get('id')
            quay_name_elem = quay.find('netex:Name', namespaces=namespaces)
            quay_private_code_elem = quay.find('netex:PrivateCode', namespaces=namespaces)
            quay_latitude_elem = quay.find('netex:Centroid/netex:Location/netex:Latitude', namespaces=namespaces)
            quay_longitude_elem = quay.find('netex:Centroid/netex:Location/netex:Longitude', namespaces=namespaces)

            # Add Quay details to StopPlace info
            quay_info = {
                'Quay ID': quay_id if quay_id else '',
                'Quay Name': quay_name_elem.text if quay_name_elem is not None else '',
                'Quay Private Code': quay_private_code_elem.text if quay_private_code_elem is not None else '',
                'Quay Latitude': quay_latitude_elem.text if quay_latitude_elem is not None else '',
                'Quay Longitude': quay_longitude_elem.text if quay_longitude_elem is not None else ''
            }

            # Merge StopPlace and Quay info into a single row
            combined_info = {**stop_info, **quay_info}
            stops.append(combined_info)

    else:
        # If no quays exist, just add StopPlace info without quay details
        stops.append(stop_info)

# Create a DataFrame from the extracted data
stops_df = pd.DataFrame(stops)

# Display the DataFrame
print(stops_df.head())
# Out:
#                         StopPlace ID   StopPlace Name StopPlace Private Code  \
# 0  SE:001:StopPlace:9021001070004000      Alhagsvägen                  70004
# 1  SE:001:StopPlace:9021001070004000      Alhagsvägen                  70004
# 2  SE:001:StopPlace:9021001070006000          Alby IP                  70006
# 3  SE:001:StopPlace:9021001070006000          Alby IP                  70006
# 4  SE:001:StopPlace:9021001070012000  Hantverkarvägen                  70012
#
#   StopPlace Latitude StopPlace Longitude                       Quay ID  \
# 0          59.234952           17.851566  SE:001:Quay:9022001070004001
# 1          59.234952           17.851566  SE:001:Quay:9022001070004002
# 2          59.237646           17.851894  SE:001:Quay:9022001070006001
# 3          59.237646           17.851894  SE:001:Quay:9022001070006002
# 4          59.235563           17.836068                           NaN
#
#      Quay Name Quay Private Code Quay Latitude Quay Longitude
# 0  Alhagsvägen                 1     59.235106      17.851514
# 1  Alhagsvägen                 2     59.234799      17.851618
# 2      Alby IP                 1     59.237838      17.851844
# 3      Alby IP                 2     59.237408      17.851931
# 4          NaN               NaN           NaN            NaN

# %%
stops_df['StopPlace ID'] = stops_df['StopPlace ID'].str.split(':').str[-1]
stops_df['Quay ID'] = stops_df['Quay ID'].str.split(':').str[-1]

# %%
stops_df.head()
# Out:
#        StopPlace ID   StopPlace Name StopPlace Private Code  \
# 0  9021001070004000      Alhagsvägen                  70004
# 1  9021001070004000      Alhagsvägen                  70004
# 2  9021001070006000          Alby IP                  70006
# 3  9021001070006000          Alby IP                  70006
# 4  9021001070012000  Hantverkarvägen                  70012
#
#   StopPlace Latitude StopPlace Longitude           Quay ID    Quay Name  \
# 0          59.234952           17.851566  9022001070004001  Alhagsvägen
# 1          59.234952           17.851566  9022001070004002  Alhagsvägen
# 2          59.237646           17.851894  9022001070006001      Alby IP
# 3          59.237646           17.851894  9022001070006002      Alby IP
# 4          59.235563           17.836068               NaN          NaN
#
#   Quay Private Code Quay Latitude Quay Longitude
# 0                 1     59.235106      17.851514
# 1                 2     59.234799      17.851618
# 2                 1     59.237838      17.851844
# 3                 2     59.237408      17.851931
# 4               NaN           NaN            NaN

# %%
points_expanded.head()
# Out:
#             Route_ID Route_Name Direction Private_Code           Point_ID  \
# 0  14010000668408490   Vigelsjö  outbound          657  14010000668408495
# 1  14010000668408490   Vigelsjö  outbound          657  14010000668408496
# 2  14010000668408490   Vigelsjö  outbound          657  14010000668408497
# 3  14010000668408490   Vigelsjö  outbound          657  14010000668408498
# 4  14010000668408490   Vigelsjö  outbound          657  14010000668408499
#
#   Order     RoutePointRef
# 0     1  9022001064146002
# 1     2  9022001062571002
# 2     3  9022001065046001
# 3     4  9022001065042001
# 4     5  9022001064478003

# %%
merged_df = pd.merge(points_expanded, stops_df, how='left', left_on='RoutePointRef', right_on='Quay ID')

# %%
merged_df
# Out:
#                 Route_ID          Route_Name Direction Private_Code  \
# 0      14010000668408490            Vigelsjö  outbound          657
# 1      14010000668408490            Vigelsjö  outbound          657
# 2      14010000668408490            Vigelsjö  outbound          657
# 3      14010000668408490            Vigelsjö  outbound          657
# 4      14010000668408490            Vigelsjö  outbound          657
# ...                  ...                 ...       ...          ...
# 69547  14010000621141260  Vallentuna station   inbound          669
# 69548  14010000621141260  Vallentuna station   inbound          669
# 69549  14010000621141260  Vallentuna station   inbound          669
# 69550  14010000621141260  Vallentuna station   inbound          669
# 69551  14010000621141260  Vallentuna station   inbound          669
#
#                 Point_ID Order     RoutePointRef      StopPlace ID  \
# 0      14010000668408495     1  9022001064146002  9021001064146000
# 1      14010000668408496     2  9022001062571002  9021001062571000
# 2      14010000668408497     3  9022001065046001  9021001065046000
# 3      14010000668408498     4  9022001065042001  9021001065042000
# 4      14010000668408499     5  9022001064478003  9021001064478000
# ...                  ...   ...               ...               ...
# 69547  14010000621141281    17  9022001059500001  9021001059500000
# 69548  14010000621141282    18  9022001059500001  9021001059500000
# 69549  14010000621141283    19  9022001059500001  9021001059500000
# 69550  14010000621141284    20  9022001059500001  9021001059500000
# 69551  14010000621141285    21  9022001060157006  9021001060157000
#
#            StopPlace Name StopPlace Private Code StopPlace Latitude  \
# 0         Campus Roslagen                  64146          59.748096
# 1         Stockholmsvägen                  62571          59.748736
# 2           Familjens hus                  65046          59.746701
# 3              Flygfältet                  65042          59.748961
# 4             Ålandsgatan                  64478          59.749684
# ...                   ...                    ...                ...
# 69547              Markim                  59500          59.590800
# 69548              Markim                  59500          59.590800
# 69549              Markim                  59500          59.590800
# 69550              Markim                  59500          59.590800
# 69551  Vallentuna station                  60157          59.534133
#
#       StopPlace Longitude           Quay ID           Quay Name  \
# 0               18.685677  9022001064146002     Campus Roslagen
# 1               18.689653  9022001062571002     Stockholmsvägen
# 2               18.691961  9022001065046001       Familjens hus
# 3               18.697201  9022001065042001          Flygfältet
# 4               18.703724  9022001064478003         Ålandsgatan
# ...                   ...               ...                 ...
# 69547           18.036978  9022001059500001              Markim
# 69548           18.036978  9022001059500001              Markim
# 69549           18.036978  9022001059500001              Markim
# 69550           18.036978  9022001059500001              Markim
# 69551           18.079634  9022001060157006  Vallentuna station
#
#       Quay Private Code Quay Latitude Quay Longitude
# 0                     2     59.748264      18.685736
# 1                     2     59.748821      18.689389
# 2                     1     59.746434      18.691735
# 3                     1     59.748912      18.697840
# 4                     3     59.749747      18.704420
# ...                 ...           ...            ...
# 69547                 1     59.590748      18.036867
# 69548                 1     59.590748      18.036867
# 69549                 1     59.590748      18.036867
# 69550                 1     59.590748      18.036867
# 69551                 6     59.533441      18.078910
#
# [69552 rows x 17 columns]

# %%
final_timetable_df.head()
# Out:
#           Journey_ID TransportMode       OperatorRef  \
# 0  14010000666428652           bus  9013001004500000
# 1  14010000666428652           bus  9013001004500000
# 2  14010000666428652           bus  9013001004500000
# 3  14010000666428652           bus  9013001004500000
# 4  14010000666428652           bus  9013001004500000
#
#                          DayTypeRef PublicCode PrivateCode  \
# 0  dfivmm59qm8phnc2c6bahh5tkhnp70hp       None         657
# 1  dfivmm59qm8phnc2c6bahh5tkhnp70hp       None         657
# 2  dfivmm59qm8phnc2c6bahh5tkhnp70hp       None         657
# 3  dfivmm59qm8phnc2c6bahh5tkhnp70hp       None         657
# 4  dfivmm59qm8phnc2c6bahh5tkhnp70hp       None         657
#
#           StopPointInJourneyPatternRef ArrivalTime DepartureTime
# 0  14019410000161291_14010000664752564        None      06:09:00
# 1  14019410000161291_14010000664752565    06:09:30      06:09:30
# 2  14019410000161291_14010000664752566    06:10:06      06:10:06
# 3  14019410000161291_14010000664752567    06:11:06      06:11:06
# 4  14019410000161291_14010000664752568    06:11:48      06:11:48

# %%
final_timetable_df['StopPointInJourneyPatternRef'] = final_timetable_df['StopPointInJourneyPatternRef'].str.split('_').str[-1]

# %%
final_timetable_df.head()
# Out:
#           Journey_ID TransportMode       OperatorRef  \
# 0  14010000666428652           bus  9013001004500000
# 1  14010000666428652           bus  9013001004500000
# 2  14010000666428652           bus  9013001004500000
# 3  14010000666428652           bus  9013001004500000
# 4  14010000666428652           bus  9013001004500000
#
#                          DayTypeRef PublicCode PrivateCode  \
# 0  dfivmm59qm8phnc2c6bahh5tkhnp70hp       None         657
# 1  dfivmm59qm8phnc2c6bahh5tkhnp70hp       None         657
# 2  dfivmm59qm8phnc2c6bahh5tkhnp70hp       None         657
# 3  dfivmm59qm8phnc2c6bahh5tkhnp70hp       None         657
# 4  dfivmm59qm8phnc2c6bahh5tkhnp70hp       None         657
#
#   StopPointInJourneyPatternRef ArrivalTime DepartureTime
# 0            14010000664752564        None      06:09:00
# 1            14010000664752565    06:09:30      06:09:30
# 2            14010000664752566    06:10:06      06:10:06
# 3            14010000664752567    06:11:06      06:11:06
# 4            14010000664752568    06:11:48      06:11:48

# %%
final_timetable_df.info
# Out:
# <bound method DataFrame.info of                 Journey_ID TransportMode       OperatorRef  \
# 0        14010000666428652           bus  9013001004500000
# 1        14010000666428652           bus  9013001004500000
# 2        14010000666428652           bus  9013001004500000
# 3        14010000666428652           bus  9013001004500000
# 4        14010000666428652           bus  9013001004500000
# ...                    ...           ...               ...
# 1312298  14010000665301478           bus  9013001004500000
# 1312299  14010000665301478           bus  9013001004500000
# 1312300  14010000665301478           bus  9013001004500000
# 1312301  14010000665301478           bus  9013001004500000
# 1312302  14010000665301478           bus  9013001004500000
#
#                                DayTypeRef PublicCode PrivateCode  \
# 0        dfivmm59qm8phnc2c6bahh5tkhnp70hp       None         657
# 1        dfivmm59qm8phnc2c6bahh5tkhnp70hp       None         657
# 2        dfivmm59qm8phnc2c6bahh5tkhnp70hp       None         657
# 3        dfivmm59qm8phnc2c6bahh5tkhnp70hp       None         657
# 4        dfivmm59qm8phnc2c6bahh5tkhnp70hp       None         657
# ...                                   ...        ...         ...
# 1312298  bncpagqso7dvr0jmc2o233d3een6g00p       None         669
# 1312299  bncpagqso7dvr0jmc2o233d3een6g00p       None         669
# 1312300  bncpagqso7dvr0jmc2o233d3een6g00p       None         669
# 1312301  bncpagqso7dvr0jmc2o233d3een6g00p       None         669
# 1312302  bncpagqso7dvr0jmc2o233d3een6g00p       None         669
#
#         StopPointInJourneyPatternRef ArrivalTime DepartureTime
# 0                  14010000664752564        None      06:09:00
# 1                  14010000664752565    06:09:30      06:09:30
# 2                  14010000664752566    06:10:06      06:10:06
# 3                  14010000664752567    06:11:06      06:11:06
# 4                  14010000664752568    06:11:48      06:11:48
# ...                              ...         ...           ...
# 1312298            14010000621141281    09:23:00      09:23:00
# 1312299            14010000621141282    09:23:00      09:23:00
# 1312300            14010000621141283    09:23:00      09:23:00
# 1312301            14010000621141284    09:23:00      09:23:00
# 1312302            14010000621141285    09:45:00          None
#
# [1312303 rows x 9 columns]>

# %%
master_data = pd.merge(merged_df, final_timetable_df, how='left', left_on='Point_ID', right_on='StopPointInJourneyPatternRef')

# %%
master_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1312332 entries, 0 to 1312331
# Data columns (total 26 columns):
#  #   Column                        Non-Null Count    Dtype
# ---  ------                        --------------    -----
#  0   Route_ID                      1312332 non-null  object
#  1   Route_Name                    1312332 non-null  object
#  2   Direction                     1312332 non-null  object
#  3   Private_Code                  1312332 non-null  object
#  4   Point_ID                      1312332 non-null  object
#  5   Order                         1312332 non-null  object
#  6   RoutePointRef                 1312332 non-null  object
#  7   StopPlace ID                  1312332 non-null  object
#  8   StopPlace Name                1312332 non-null  object
#  9   StopPlace Private Code        1312332 non-null  object
#  10  StopPlace Latitude            1312332 non-null  object
#  11  StopPlace Longitude           1312332 non-null  object
#  12  Quay ID                       1312332 non-null  object
#  13  Quay Name                     1312332 non-null  object
#  14  Quay Private Code             1312332 non-null  object
#  15  Quay Latitude                 1312332 non-null  object
#  16  Quay Longitude                1312332 non-null  object
#  17  Journey_ID                    1312303 non-null  object
#  18  TransportMode                 1312303 non-null  object
#  19  OperatorRef                   1312303 non-null  object
#  20  DayTypeRef                    1312303 non-null  object
#  21  PublicCode                    0 non-null        object
#  22  PrivateCode                   1312303 non-null  object
#  23  StopPointInJourneyPatternRef  1312303 non-null  object
#  24  ArrivalTime                   1246174 non-null  object
#  25  DepartureTime                 1246174 non-null  object
# dtypes: object(26)
# memory usage: 260.3+ MB

# %%
master_data
# Out:
#                   Route_ID          Route_Name Direction Private_Code  \
# 0        14010000668408490            Vigelsjö  outbound          657
# 1        14010000668408490            Vigelsjö  outbound          657
# 2        14010000668408490            Vigelsjö  outbound          657
# 3        14010000668408490            Vigelsjö  outbound          657
# 4        14010000668408490            Vigelsjö  outbound          657
# ...                    ...                 ...       ...          ...
# 1312327  14010000621141260  Vallentuna station   inbound          669
# 1312328  14010000621141260  Vallentuna station   inbound          669
# 1312329  14010000621141260  Vallentuna station   inbound          669
# 1312330  14010000621141260  Vallentuna station   inbound          669
# 1312331  14010000621141260  Vallentuna station   inbound          669
#
#                   Point_ID Order     RoutePointRef      StopPlace ID  \
# 0        14010000668408495     1  9022001064146002  9021001064146000
# 1        14010000668408495     1  9022001064146002  9021001064146000
# 2        14010000668408495     1  9022001064146002  9021001064146000
# 3        14010000668408495     1  9022001064146002  9021001064146000
# 4        14010000668408495     1  9022001064146002  9021001064146000
# ...                    ...   ...               ...               ...
# 1312327  14010000621141284    20  9022001059500001  9021001059500000
# 1312328  14010000621141285    21  9022001060157006  9021001060157000
# 1312329  14010000621141285    21  9022001060157006  9021001060157000
# 1312330  14010000621141285    21  9022001060157006  9021001060157000
# 1312331  14010000621141285    21  9022001060157006  9021001060157000
#
#              StopPlace Name StopPlace Private Code  ... Quay Longitude  \
# 0           Campus Roslagen                  64146  ...      18.685736
# 1           Campus Roslagen                  64146  ...      18.685736
# 2           Campus Roslagen                  64146  ...      18.685736
# 3           Campus Roslagen                  64146  ...      18.685736
# 4           Campus Roslagen                  64146  ...      18.685736
# ...                     ...                    ...  ...            ...
# 1312327              Markim                  59500  ...      18.036867
# 1312328  Vallentuna station                  60157  ...      18.078910
# 1312329  Vallentuna station                  60157  ...      18.078910
# 1312330  Vallentuna station                  60157  ...      18.078910
# 1312331  Vallentuna station                  60157  ...      18.078910
#
#                 Journey_ID TransportMode       OperatorRef  \
# 0        14010000668408800           bus  9013001004500000
# 1        14010000668409048           bus  9013001004500000
# 2        14010000668409757           bus  9013001004500000
# 3        14010000668410654           bus  9013001004500000
# 4        14010000668411017           bus  9013001004500000
# ...                    ...           ...               ...
# 1312327  14010000665301478           bus  9013001004500000
# 1312328  14010000630305369           bus  9013001004500000
# 1312329  14010000665310499           bus  9013001004500000
# 1312330  14010000665318371           bus  9013001004500000
# 1312331  14010000665301478           bus  9013001004500000
#
#                                DayTypeRef PublicCode PrivateCode  \
# 0        62vdge1e16h1c23r2ie5akj4600d2l3r       None         657
# 1        62vdge1e16h1c23r2ie5akj4600d2l3r       None         657
# 2        62vdge1e16h1c23r2ie5akj4600d2l3r       None         657
# 3        62vdge1e16h1c23r2ie5akj4600d2l3r       None         657
# 4        62vdge1e16h1c23r2ie5akj4600d2l3r       None         657
# ...                                   ...        ...         ...
# 1312327  bncpagqso7dvr0jmc2o233d3een6g00p       None         669
# 1312328  bncpagqso7dvr0jmc2o233d3een6g00p       None         669
# 1312329  bncpagqso7dvr0jmc2o233d3een6g00p       None         669
# 1312330  bncpagqso7dvr0jmc2o233d3een6g00p       None         669
# 1312331  bncpagqso7dvr0jmc2o233d3een6g00p       None         669
#
#         StopPointInJourneyPatternRef ArrivalTime DepartureTime
# 0                  14010000668408495        None      06:09:00
# 1                  14010000668408495        None      07:08:00
# 2                  14010000668408495        None      11:08:00
# 3                  14010000668408495        None      16:08:00
# 4                  14010000668408495        None      18:08:00
# ...                              ...         ...           ...
# 1312327            14010000621141284    09:23:00      09:23:00
# 1312328            14010000621141285    19:48:00          None
# 1312329            14010000621141285    12:12:00          None
# 1312330            14010000621141285    14:21:00          None
# 1312331            14010000621141285    09:45:00          None
#
# [1312332 rows x 26 columns]

# %%
master_data.to_csv('routes_master_data.csv.gz', index=False, compression='gzip')
